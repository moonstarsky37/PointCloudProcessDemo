# %% [markdown]
# # 信義路

# %%
import os, sys, copy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import laspy
from tqdm.notebook import tqdm
from numba import jit, njit, prange
from glob import glob

# %%
las_folder = r"P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS/"
fn_list = glob(las_folder+"*.las")
fn = fn_list[0]
print(fn, os.path.basename(fn))
# Out:
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\001.las 001.las

# %%
@njit(parallel=True)
def get_upper_bound(points, min_points_num, upper_bound):
    points_max = np.max(points)
    points_min = np.min(points)
    for i in prange(np.int(points_max-points_min)):
        if np.sum(points_max-i >= points) < min_points_num:
            return upper_bound
        else:
            upper_bound = points_max-i

@njit(parallel=True)
def get_lower_bound(points, min_points_num, lower_bound):
    points_max = np.max(points)
    points_min = np.min(points)
    for i in prange(np.int(points_max-points_min)):
        if np.sum(points_min+i <= points) < min_points_num:
            return lower_bound
        else:
            lower_bound = points_min+i

# %%
# %time
for fn in tqdm(fn_list):
    print(fn)
    inFile = laspy.file.File(os.path.join(las_folder, fn), mode='rw') # read a las file
    las_points = inFile.points.copy()
    min_points_num = int(inFile.x.shape[0]*.999)
    x_upper_bound, y_upper_bound, z_upper_bound = inFile.header.max
    x_lower_bound, y_lower_bound, z_lower_bound = inFile.header.min
    x_upper_bound_new = get_upper_bound(inFile.x, min_points_num, x_upper_bound)
    x_lower_bound_new = get_lower_bound(inFile.x, min_points_num, x_lower_bound)
    y_upper_bound_new = get_upper_bound(inFile.y, min_points_num, y_upper_bound)
    y_lower_bound_new = get_lower_bound(inFile.y, min_points_num, y_lower_bound)
    z_upper_bound_new = get_upper_bound(inFile.z, min_points_num, z_upper_bound)
    z_lower_bound_new = get_lower_bound(inFile.z, min_points_num, z_lower_bound)
    X_valid = (x_lower_bound_new <= inFile.x) * (x_upper_bound_new >= inFile.x)
    Y_valid = (y_lower_bound_new <= inFile.y) * (y_upper_bound_new >= inFile.y)
    Z_valid = (z_lower_bound_new <= inFile.z) * (z_upper_bound_new >= inFile.z)
    good_indices = X_valid * Y_valid * Z_valid
    good_points = las_points[good_indices]
    print(f"Original numbers of pts = {las_points.shape[0]}, numbers of filtering pts = {good_points.shape[0]}, ratio = {good_points.shape[0]/las_points.shape[0]}")
    inFile.header.max = [x_upper_bound_new, y_upper_bound_new, z_upper_bound_new] 
    inFile.header.min = [x_lower_bound_new, y_lower_bound_new, z_lower_bound_new] 
    outFile = laspy.file.File(f"P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_過濾極值點_LAS/{os.path.basename(fn)}", mode='w', header=inFile.header)
    outFile.points =  inFile.points[good_indices] 
    outFile.close() 
    inFile.close()
# Out:
# Wall time: 0 ns
# HBox(children=(FloatProgress(value=0.0, max=303.0), HTML(value='')))
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\001.las
# Original numbers of pts = 4588024, numbers of filtering pts = 4578749, ratio = 0.9979784325452526
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\002.las
# Original numbers of pts = 8760640, numbers of filtering pts = 8748964, ratio = 0.9986672206596778
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\003.las
# Original numbers of pts = 4135362, numbers of filtering pts = 4131255, ratio = 0.9990068584080426
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\004.las
# Original numbers of pts = 46830917, numbers of filtering pts = 46745023, ratio = 0.9981658697821356
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\005.las
# Original numbers of pts = 3093722, numbers of filtering pts = 3086578, ratio = 0.9976908073834688
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\006.las
# Original numbers of pts = 62624, numbers of filtering pts = 62497, ratio = 0.9979720235053654
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\007.las
# Original numbers of pts = 133662963, numbers of filtering pts = 133426527, ratio = 0.9982311031066998
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\008.las
# Original numbers of pts = 112530627, numbers of filtering pts = 112402533, ratio = 0.9988616965583956
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\009.las
# Original numbers of pts = 102456834, numbers of filtering pts = 102342267, ratio = 0.9988818022622092
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\010.las
# Original numbers of pts = 152976904, numbers of filtering pts = 152801322, ratio = 0.9988522319682976
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\011.las
# Original numbers of pts = 5692690, numbers of filtering pts = 5687472, ratio = 0.9990833858861101
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\012.las
# Original numbers of pts = 2906090, numbers of filtering pts = 2900359, ratio = 0.9980279344411219
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\013.las
# Original numbers of pts = 98082752, numbers of filtering pts = 97892263, ratio = 0.9980578746403853
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\014.las
# Original numbers of pts = 1448551, numbers of filtering pts = 1447472, ratio = 0.9992551177003778
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\015.las
# Original numbers of pts = 19282967, numbers of filtering pts = 19250107, ratio = 0.9982959053967162
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\016.las
# Original numbers of pts = 80815865, numbers of filtering pts = 80703498, ratio = 0.9986095923121036
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\017.las
# Original numbers of pts = 850255, numbers of filtering pts = 848808, ratio = 0.9982981576115401
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\018.las
# Original numbers of pts = 31908184, numbers of filtering pts = 31870924, ratio = 0.9988322745036196
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\019.las
# Original numbers of pts = 134228702, numbers of filtering pts = 133957729, ratio = 0.9979812588815766
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\020.las
# Original numbers of pts = 320005, numbers of filtering pts = 319679, ratio = 0.9989812659177201
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\021.las
# Original numbers of pts = 41881148, numbers of filtering pts = 41816490, ratio = 0.9984561550223027
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\022.las
# Original numbers of pts = 36187984, numbers of filtering pts = 36126104, ratio = 0.9982900401415011
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\023.las
# Original numbers of pts = 506812, numbers of filtering pts = 505849, ratio = 0.9980998871376369
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\024.las
# Original numbers of pts = 320545, numbers of filtering pts = 320520, ratio = 0.9999220078304139
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\025.las
# Original numbers of pts = 48768732, numbers of filtering pts = 48670536, ratio = 0.9979864967577996
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\026.las
# Original numbers of pts = 18760951, numbers of filtering pts = 18717775, ratio = 0.9976986241262503
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\027.las
# Original numbers of pts = 203368, numbers of filtering pts = 203280, ratio = 0.9995672868887927
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\028.las
# Original numbers of pts = 59025602, numbers of filtering pts = 58951213, ratio = 0.9987397163691782
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\029.las
# Original numbers of pts = 9998697, numbers of filtering pts = 9996419, ratio = 0.9997721703137918
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\030.las
# Original numbers of pts = 1300593, numbers of filtering pts = 1298090, ratio = 0.9980754932557687
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\031.las
# Original numbers of pts = 406859, numbers of filtering pts = 406565, ratio = 0.9992773909388756
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\032.las
# Original numbers of pts = 63350849, numbers of filtering pts = 63261814, ratio = 0.9985945728998833
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\033.las
# Original numbers of pts = 280788, numbers of filtering pts = 280129, ratio = 0.9976530336054248
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\034.las
# Original numbers of pts = 1471119, numbers of filtering pts = 1467343, ratio = 0.9974332463927119
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\035.las
# Original numbers of pts = 74997281, numbers of filtering pts = 74863295, ratio = 0.998213455231797
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\036.las
# Original numbers of pts = 1925962, numbers of filtering pts = 1925352, ratio = 0.999683275163269
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\037.las
# Original numbers of pts = 2857713, numbers of filtering pts = 2853086, ratio = 0.9983808730967736
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\038.las
# Original numbers of pts = 95562107, numbers of filtering pts = 95415917, ratio = 0.9984702095360873
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\039.las
# Original numbers of pts = 1003896, numbers of filtering pts = 1003564, ratio = 0.9996692884521903
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\040.las
# Original numbers of pts = 12988603, numbers of filtering pts = 12970864, ratio = 0.9986342642083987
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\041.las
# Original numbers of pts = 49397314, numbers of filtering pts = 49373741, ratio = 0.9995227878179773
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\042.las
# Original numbers of pts = 6323751, numbers of filtering pts = 6312352, ratio = 0.9981974306072456
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\043.las
# Original numbers of pts = 12900, numbers of filtering pts = 12879, ratio = 0.9983720930232558
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\044.las
# Original numbers of pts = 33346608, numbers of filtering pts = 33293375, ratio = 0.9984036457321236
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\045.las
# Original numbers of pts = 56158278, numbers of filtering pts = 56048629, ratio = 0.9980475006730085
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\046.las
# Original numbers of pts = 395108, numbers of filtering pts = 394553, ratio = 0.9985953207730545
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\047.las
# Original numbers of pts = 38924846, numbers of filtering pts = 38849055, ratio = 0.9980528888926111
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\048.las
# Original numbers of pts = 29080114, numbers of filtering pts = 29063455, ratio = 0.9994271342952782
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\049.las
# Original numbers of pts = 3943982, numbers of filtering pts = 3938455, ratio = 0.9985986244359127
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\050.las
# Original numbers of pts = 344861, numbers of filtering pts = 344393, ratio = 0.9986429314999377
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\051.las
# Original numbers of pts = 56812755, numbers of filtering pts = 56711584, ratio = 0.9982192203141707
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\052.las
# Original numbers of pts = 242208774, numbers of filtering pts = 242128740, ratio = 0.9996695660579167
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\053.las
# Original numbers of pts = 110953455, numbers of filtering pts = 110785577, ratio = 0.9984869511273894
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\054.las
# Original numbers of pts = 105060981, numbers of filtering pts = 104952594, ratio = 0.9989683420146248
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\055.las
# Original numbers of pts = 24766385, numbers of filtering pts = 24743149, ratio = 0.9990617928292724
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\056.las
# Original numbers of pts = 99785, numbers of filtering pts = 99686, ratio = 0.9990078669138648
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\057.las
# Original numbers of pts = 3207563, numbers of filtering pts = 3204944, ratio = 0.9991834922649999
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\058.las
# Original numbers of pts = 65497807, numbers of filtering pts = 65431097, ratio = 0.9989814926169971
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\059-1_0814.las
# Original numbers of pts = 147861551, numbers of filtering pts = 147677328, ratio = 0.9987540844881304
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\059-2_0814.las
# Original numbers of pts = 175943173, numbers of filtering pts = 175743444, ratio = 0.998864809605315
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\059.las
# Original numbers of pts = 324442627, numbers of filtering pts = 323866967, ratio = 0.9982256955403089
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\060.las
# Original numbers of pts = 190945894, numbers of filtering pts = 190782425, ratio = 0.9991438988470734
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\061.las
# Original numbers of pts = 34498932, numbers of filtering pts = 34484888, ratio = 0.9995929149342943
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\062.las
# Original numbers of pts = 8612254, numbers of filtering pts = 8596229, ratio = 0.9981392792177286
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\063.las
# Original numbers of pts = 16435, numbers of filtering pts = 16390, ratio = 0.9972619409796166
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\064.las
# Original numbers of pts = 8100997, numbers of filtering pts = 8085195, ratio = 0.9980493758978062
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\065.las
# Original numbers of pts = 18336290, numbers of filtering pts = 18313391, ratio = 0.9987511650393837
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\066.las
# Original numbers of pts = 72552892, numbers of filtering pts = 72481763, ratio = 0.9990196255719207
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\067.las
# Original numbers of pts = 34888525, numbers of filtering pts = 34812588, ratio = 0.9978234390820477
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\068.las
# Original numbers of pts = 2546486, numbers of filtering pts = 2541922, ratio = 0.9982077262549254
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\069.las
# Original numbers of pts = 134260, numbers of filtering pts = 134147, ratio = 0.9991583494711753
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\070.las
# Original numbers of pts = 963420, numbers of filtering pts = 961665, ratio = 0.9981783645761974
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\071.las
# Original numbers of pts = 19908054, numbers of filtering pts = 19883796, ratio = 0.9987814981815902
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\072.las
# Original numbers of pts = 49361307, numbers of filtering pts = 49314399, ratio = 0.9990497010137921
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\073.las
# Original numbers of pts = 56810720, numbers of filtering pts = 56714966, ratio = 0.9983145082477392
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\074.las
# Original numbers of pts = 2553964, numbers of filtering pts = 2552119, ratio = 0.9992775935761037
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\075.las
# Original numbers of pts = 367940, numbers of filtering pts = 367312, ratio = 0.9982931999782573
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\076.las
# Original numbers of pts = 1228180, numbers of filtering pts = 1225413, ratio = 0.9977470729046231
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\077.las
# Original numbers of pts = 31468622, numbers of filtering pts = 31440247, ratio = 0.9990983081496229
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\078.las
# Original numbers of pts = 59631865, numbers of filtering pts = 59605427, ratio = 0.9995566464339158
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\079.las
# Original numbers of pts = 47890271, numbers of filtering pts = 47816970, ratio = 0.998469396842628
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\080.las
# Original numbers of pts = 6034306, numbers of filtering pts = 6030790, ratio = 0.999417331504236
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\081.las
# Original numbers of pts = 45549, numbers of filtering pts = 45538, ratio = 0.9997585018331906
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\082.las
# Original numbers of pts = 2865621, numbers of filtering pts = 2857937, ratio = 0.9973185567805373
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\083.las
# Original numbers of pts = 98843270, numbers of filtering pts = 98642680, ratio = 0.9979706256177077
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\084.las
# Original numbers of pts = 86561998, numbers of filtering pts = 86448633, ratio = 0.9986903606360842
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\085.las
# Original numbers of pts = 58377515, numbers of filtering pts = 58229084, ratio = 0.9974573943409547
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\086.las
# Original numbers of pts = 1949879, numbers of filtering pts = 1946673, ratio = 0.9983557954108947
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\087.las
# Original numbers of pts = 1995567, numbers of filtering pts = 1990757, ratio = 0.9975896574757951
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\088.las
# Original numbers of pts = 39945329, numbers of filtering pts = 39904072, ratio = 0.9989671633446804
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\089.las
# Original numbers of pts = 62056335, numbers of filtering pts = 61920212, ratio = 0.9978064608552858
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\090.las
# Original numbers of pts = 75927445, numbers of filtering pts = 75684435, ratio = 0.9967994445223332
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\091.las
# Original numbers of pts = 31534655, numbers of filtering pts = 31492169, ratio = 0.9986527203167436
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\092.las
# Original numbers of pts = 28974747, numbers of filtering pts = 28924577, ratio = 0.9982684922149623
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\093.las
# Original numbers of pts = 32583244, numbers of filtering pts = 32508654, ratio = 0.9977107865625657
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\094.las
# Original numbers of pts = 539811, numbers of filtering pts = 538949, ratio = 0.9984031448043852
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\095.las
# Original numbers of pts = 313663, numbers of filtering pts = 313662, ratio = 0.9999968118649634
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\096.las
# Original numbers of pts = 6882309, numbers of filtering pts = 6869565, ratio = 0.9981482958698891
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\097.las
# Original numbers of pts = 45466861, numbers of filtering pts = 45418807, ratio = 0.9989430983590444
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\098.las
# Original numbers of pts = 71692102, numbers of filtering pts = 71611592, ratio = 0.9988770032157797
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\099.las
# Original numbers of pts = 11944120, numbers of filtering pts = 11910360, ratio = 0.9971735046198464
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\100.las
# Original numbers of pts = 28210, numbers of filtering pts = 28178, ratio = 0.9988656504785537
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\101.las
# Original numbers of pts = 25457, numbers of filtering pts = 25439, ratio = 0.999292925325058
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\102.las
# Original numbers of pts = 22001450, numbers of filtering pts = 21995940, ratio = 0.999749561960689
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\103.las
# Original numbers of pts = 65445778, numbers of filtering pts = 65377596, ratio = 0.998958191008135
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\104.las
# Original numbers of pts = 14523901, numbers of filtering pts = 14519458, ratio = 0.9996940904513189
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\105.las
# Original numbers of pts = 12250153, numbers of filtering pts = 12219644, ratio = 0.9975095004935857
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\106.las
# Original numbers of pts = 1213265, numbers of filtering pts = 1211324, ratio = 0.9984001846257825
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\107.las
# Original numbers of pts = 2353340, numbers of filtering pts = 2350347, ratio = 0.9987281905716981
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\108.las
# Original numbers of pts = 83050396, numbers of filtering pts = 82918543, ratio = 0.9984123736146905
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\109.las
# Original numbers of pts = 6779764, numbers of filtering pts = 6768511, ratio = 0.9983402077122449
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\110.las
# Original numbers of pts = 138866, numbers of filtering pts = 138740, ratio = 0.9990926504687972
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\111.las
# Original numbers of pts = 1530082, numbers of filtering pts = 1529952, ratio = 0.9999150372332986
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\112.las
# Original numbers of pts = 10575786, numbers of filtering pts = 10554029, ratio = 0.9979427533802215
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\113.las
# Original numbers of pts = 50593533, numbers of filtering pts = 50474593, ratio = 0.9976491066555878
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\114.las
# Original numbers of pts = 56366198, numbers of filtering pts = 56242873, ratio = 0.9978120752441029
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\115.las
# Original numbers of pts = 23273588, numbers of filtering pts = 23222103, ratio = 0.9977878357217632
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\116.las
# Original numbers of pts = 1087505, numbers of filtering pts = 1086092, ratio = 0.9987006956289857
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\117.las
# Original numbers of pts = 275970, numbers of filtering pts = 275229, ratio = 0.9973149255353843
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\118.las
# Original numbers of pts = 88913, numbers of filtering pts = 88794, ratio = 0.9986616130374636
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\119.las
# Original numbers of pts = 175463, numbers of filtering pts = 174952, ratio = 0.9970877051002206
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\120.las
# Original numbers of pts = 2463823, numbers of filtering pts = 2460860, ratio = 0.9987973973779772
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\121.las
# Original numbers of pts = 53215128, numbers of filtering pts = 53157442, ratio = 0.998915984943229
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\122.las
# Original numbers of pts = 17926717, numbers of filtering pts = 17915980, ratio = 0.9994010615552195
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\123.las
# Original numbers of pts = 3754031, numbers of filtering pts = 3745567, ratio = 0.9977453569243301
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\124.las
# Original numbers of pts = 309459, numbers of filtering pts = 309165, ratio = 0.9990499549213304
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\125.las
# Original numbers of pts = 527898, numbers of filtering pts = 527441, ratio = 0.999134302459945
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\126.las
# Original numbers of pts = 707353, numbers of filtering pts = 706218, ratio = 0.9983954263288627
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\127.las
# Original numbers of pts = 71574889, numbers of filtering pts = 71461348, ratio = 0.9984136755000765
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\128.las
# Original numbers of pts = 6983132, numbers of filtering pts = 6980363, ratio = 0.999603473054784
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\129.las
# Original numbers of pts = 2869, numbers of filtering pts = 2867, ratio = 0.9993028929940746
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\130.las
# Original numbers of pts = 206819, numbers of filtering pts = 206333, ratio = 0.9976501191863417
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\131.las
# Original numbers of pts = 29714084, numbers of filtering pts = 29610380, ratio = 0.9965099378463088
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\132.las
# Original numbers of pts = 97869359, numbers of filtering pts = 97723120, ratio = 0.998505773395328
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\133.las
# Original numbers of pts = 58688272, numbers of filtering pts = 58625850, ratio = 0.9989363803384772
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\134.las
# Original numbers of pts = 52830934, numbers of filtering pts = 52681029, ratio = 0.9971625525303035
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\135.las
# Original numbers of pts = 47468035, numbers of filtering pts = 47377134, ratio = 0.9980850060467007
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\136.las
# Original numbers of pts = 43002099, numbers of filtering pts = 42916650, ratio = 0.9980129109511607
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\137.las
# Original numbers of pts = 39325148, numbers of filtering pts = 39268723, ratio = 0.998565167510622
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\138.las
# Original numbers of pts = 100843108, numbers of filtering pts = 100562058, ratio = 0.9972129974415307
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\139.las
# Original numbers of pts = 35995712, numbers of filtering pts = 35923373, ratio = 0.9979903439609695
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\140.las
# Original numbers of pts = 41699176, numbers of filtering pts = 41637431, ratio = 0.9985192752969507
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\141.las
# Original numbers of pts = 31200462, numbers of filtering pts = 31138081, ratio = 0.9980006385802876
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\142.las
# Original numbers of pts = 32692672, numbers of filtering pts = 32641408, ratio = 0.9984319421795808
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\143.las
# Original numbers of pts = 34315150, numbers of filtering pts = 34262149, ratio = 0.9984554635488989
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\144.las
# Original numbers of pts = 33713714, numbers of filtering pts = 33649384, ratio = 0.998091874422379
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\145.las
# Original numbers of pts = 36858286, numbers of filtering pts = 36846896, ratio = 0.9996909785767032
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\146.las
# Original numbers of pts = 16362430, numbers of filtering pts = 16333752, ratio = 0.9982473263445588
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\147.las
# Original numbers of pts = 16349996, numbers of filtering pts = 16327651, ratio = 0.9986333329989806
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\148.las
# Original numbers of pts = 11459064, numbers of filtering pts = 11438143, ratio = 0.9981742836936769
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\149.las
# Original numbers of pts = 9081213, numbers of filtering pts = 9074220, ratio = 0.9992299486863704
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\150.las
# Original numbers of pts = 13466284, numbers of filtering pts = 13447031, ratio = 0.998570281155514
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\151.las
# Original numbers of pts = 16852281, numbers of filtering pts = 16837940, ratio = 0.9991490172754656
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\152.las
# Original numbers of pts = 31704060, numbers of filtering pts = 31626050, ratio = 0.9975394318582541
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\153.las
# Original numbers of pts = 11055934, numbers of filtering pts = 11050604, ratio = 0.9995179059498727
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\154.las
# Original numbers of pts = 12554238, numbers of filtering pts = 12541792, ratio = 0.9990086216304008
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\155.las
# Original numbers of pts = 7448935, numbers of filtering pts = 7436177, ratio = 0.9982872719388745
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\156.las
# Original numbers of pts = 7084940, numbers of filtering pts = 7071306, ratio = 0.998075636490923
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\157.las
# Original numbers of pts = 4243173, numbers of filtering pts = 4240501, ratio = 0.9993702825692
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\158.las
# Original numbers of pts = 1474884, numbers of filtering pts = 1474166, ratio = 0.9995131820536395
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\159.las
# Original numbers of pts = 2556054, numbers of filtering pts = 2553559, ratio = 0.9990238860368365
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\160.las
# Original numbers of pts = 1609797, numbers of filtering pts = 1607432, ratio = 0.9985308706625742
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\161.las
# Original numbers of pts = 656646, numbers of filtering pts = 654996, ratio = 0.9974872305625863
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\162.las
# Original numbers of pts = 177152, numbers of filtering pts = 176815, ratio = 0.9980976788294798
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\163.las
# Original numbers of pts = 933867, numbers of filtering pts = 931908, ratio = 0.9979022708801146
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\164.las
# Original numbers of pts = 1581729, numbers of filtering pts = 1576135, ratio = 0.9964633638252823
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\165.las
# Original numbers of pts = 1074901, numbers of filtering pts = 1072535, ratio = 0.9977988670584547
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\166.las
# Original numbers of pts = 728843, numbers of filtering pts = 727510, ratio = 0.9981710738801086
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\167.las
# Original numbers of pts = 95991, numbers of filtering pts = 95788, ratio = 0.9978852184058922
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\168.las
# Original numbers of pts = 304888, numbers of filtering pts = 304102, ratio = 0.9974220041457846
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\169.las
# Original numbers of pts = 689998, numbers of filtering pts = 688500, ratio = 0.9978289792144325
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\170.las
# Original numbers of pts = 7409104, numbers of filtering pts = 7398420, ratio = 0.9985579902779067
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\171.las
# Original numbers of pts = 160745, numbers of filtering pts = 160573, ratio = 0.998929982270055
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\172.las
# Original numbers of pts = 2112630, numbers of filtering pts = 2105440, ratio = 0.9965966591405025
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\173.las
# Original numbers of pts = 26497746, numbers of filtering pts = 26456625, ratio = 0.9984481321543349
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\174.las
# Original numbers of pts = 26450845, numbers of filtering pts = 26428207, ratio = 0.9991441483249401
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\175.las
# Original numbers of pts = 3379191, numbers of filtering pts = 3379156, ratio = 0.9999896424913537
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\176.las
# Original numbers of pts = 281278, numbers of filtering pts = 280880, ratio = 0.9985850297570376
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\177.las
# Original numbers of pts = 241274, numbers of filtering pts = 241119, ratio = 0.9993575768628199
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\178.las
# Original numbers of pts = 895150, numbers of filtering pts = 894406, ratio = 0.9991688543819471
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\179.las
# Original numbers of pts = 1710592, numbers of filtering pts = 1708720, ratio = 0.9989056420233463
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\180.las
# Original numbers of pts = 65249928, numbers of filtering pts = 65128854, ratio = 0.9981444577226201
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\181.las
# Original numbers of pts = 3734722, numbers of filtering pts = 3732376, ratio = 0.9993718407956469
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\182.las
# Original numbers of pts = 907512, numbers of filtering pts = 906273, ratio = 0.9986347287969746
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\183.las
# Original numbers of pts = 23211487, numbers of filtering pts = 23167920, ratio = 0.9981230414061796
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\184.las
# Original numbers of pts = 2640373, numbers of filtering pts = 2638139, ratio = 0.9991539074214135
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\185.las
# Original numbers of pts = 1203818, numbers of filtering pts = 1200842, ratio = 0.997527865507909
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\186.las
# Original numbers of pts = 97544, numbers of filtering pts = 97224, ratio = 0.9967194291806775
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\187.las
# Original numbers of pts = 466093, numbers of filtering pts = 465581, ratio = 0.9989015067808356
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\188.las
# Original numbers of pts = 1383738, numbers of filtering pts = 1380737, ratio = 0.9978312368381875
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\189.las
# Original numbers of pts = 10789774, numbers of filtering pts = 10773861, ratio = 0.9985251776357874
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\190.las
# Original numbers of pts = 13631698, numbers of filtering pts = 13613239, ratio = 0.9986458766912236
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\191.las
# Original numbers of pts = 43180599, numbers of filtering pts = 43085631, ratio = 0.9978006789576958
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\192.las
# Original numbers of pts = 15211352, numbers of filtering pts = 15195965, ratio = 0.9989884528344357
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\193.las
# Original numbers of pts = 15456526, numbers of filtering pts = 15427602, ratio = 0.9981286868731046
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\194.las
# Original numbers of pts = 13301203, numbers of filtering pts = 13279283, ratio = 0.9983520287601054
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\195.las
# Original numbers of pts = 28899145, numbers of filtering pts = 28867160, ratio = 0.998893219851314
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\196.las
# Original numbers of pts = 30849268, numbers of filtering pts = 30806450, ratio = 0.9986120254133745
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\197.las
# Original numbers of pts = 60893454, numbers of filtering pts = 60799222, ratio = 0.9984525101827858
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\198.las
# Original numbers of pts = 98300867, numbers of filtering pts = 98142593, ratio = 0.9983899022986237
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\199.las
# Original numbers of pts = 32366844, numbers of filtering pts = 32295155, ratio = 0.997785109972415
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\200.las
# Original numbers of pts = 37448915, numbers of filtering pts = 37378877, ratio = 0.9981297722510786
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\201.las
# Original numbers of pts = 34268687, numbers of filtering pts = 34206594, ratio = 0.9981880543015844
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\202.las
# Original numbers of pts = 35517837, numbers of filtering pts = 35451157, ratio = 0.9981226334250027
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\203.las
# Original numbers of pts = 64328496, numbers of filtering pts = 64232937, ratio = 0.9985145152468666
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\204.las
# Original numbers of pts = 48004105, numbers of filtering pts = 47922521, ratio = 0.998300478677813
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\205.las
# Original numbers of pts = 114084246, numbers of filtering pts = 113855156, ratio = 0.9979919225657151
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\206.las
# Original numbers of pts = 49138125, numbers of filtering pts = 49129237, ratio = 0.9998191221175005
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\207.las
# Original numbers of pts = 51470138, numbers of filtering pts = 51390807, ratio = 0.9984586985175754
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\208.las
# Original numbers of pts = 47933706, numbers of filtering pts = 47845027, ratio = 0.9981499657047173
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\209.las
# Original numbers of pts = 40378621, numbers of filtering pts = 40307126, ratio = 0.9982293848024181
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\210.las
# Original numbers of pts = 32986997, numbers of filtering pts = 32937958, ratio = 0.9985133839251873
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\211.las
# Original numbers of pts = 85139890, numbers of filtering pts = 84972322, ratio = 0.9980318508750716
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\212.las
# Original numbers of pts = 73968343, numbers of filtering pts = 73818807, ratio = 0.9979783783989862
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\213.las
# Original numbers of pts = 55482716, numbers of filtering pts = 55372382, ratio = 0.9980113806973689
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\214.las
# Original numbers of pts = 50967627, numbers of filtering pts = 50822696, ratio = 0.9971564106761337
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\215.las
# Original numbers of pts = 52853564, numbers of filtering pts = 52701853, ratio = 0.997129597542372
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\216.las
# Original numbers of pts = 46716187, numbers of filtering pts = 46573249, ratio = 0.9969402896687608
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\217.las
# Original numbers of pts = 42905011, numbers of filtering pts = 42828416, ratio = 0.9982147772902331
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\218.las
# Original numbers of pts = 62682984, numbers of filtering pts = 62591096, ratio = 0.9985340838272792
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\219.las
# Original numbers of pts = 98482705, numbers of filtering pts = 98342527, ratio = 0.9985766231745971
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\220.las
# Original numbers of pts = 60224430, numbers of filtering pts = 60105723, ratio = 0.9980289228142134
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\221.las
# Original numbers of pts = 51138772, numbers of filtering pts = 51041196, ratio = 0.9980919369749434
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\222.las
# Original numbers of pts = 81740695, numbers of filtering pts = 81598501, ratio = 0.9982604258503063
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\223.las
# Original numbers of pts = 166872713, numbers of filtering pts = 166401407, ratio = 0.9971756556747537
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\224.las
# Original numbers of pts = 84072842, numbers of filtering pts = 83894859, ratio = 0.9978829905619225
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\225.las
# Original numbers of pts = 170427417, numbers of filtering pts = 170050465, ratio = 0.9977881962501374
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\226.las
# Original numbers of pts = 111006993, numbers of filtering pts = 110907321, ratio = 0.9991021106210849
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\227.las
# Original numbers of pts = 54357012, numbers of filtering pts = 54306798, ratio = 0.9990762185382817
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\228.las
# Original numbers of pts = 37861083, numbers of filtering pts = 37786388, ratio = 0.9980271298631368
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\229.las
# Original numbers of pts = 36681070, numbers of filtering pts = 36665806, ratio = 0.9995838725533361
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\230.las
# Original numbers of pts = 35876316, numbers of filtering pts = 35844274, ratio = 0.9991068759679784
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\231.las
# Original numbers of pts = 32824256, numbers of filtering pts = 32787597, ratio = 0.998883173467816
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\232.las
# Original numbers of pts = 35175242, numbers of filtering pts = 35125337, ratio = 0.9985812464346372
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\233.las
# Original numbers of pts = 109883808, numbers of filtering pts = 109749241, ratio = 0.9987753700709026
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\234.las
# Original numbers of pts = 46284029, numbers of filtering pts = 46210372, ratio = 0.9984085871175995
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\235.las
# Original numbers of pts = 42058139, numbers of filtering pts = 41992332, ratio = 0.9984353325761751
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\236.las
# Original numbers of pts = 58108886, numbers of filtering pts = 58010094, ratio = 0.9982998813640998
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\237.las
# Original numbers of pts = 73679896, numbers of filtering pts = 73574230, ratio = 0.9985658774545502
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\238.las
# Original numbers of pts = 43599031, numbers of filtering pts = 43512664, ratio = 0.9980190614786829
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\239.las
# Original numbers of pts = 24888619, numbers of filtering pts = 24846274, ratio = 0.9982986199435172
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\240.las
# Original numbers of pts = 19302477, numbers of filtering pts = 19277617, ratio = 0.9987120823923271
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\241.las
# Original numbers of pts = 16894851, numbers of filtering pts = 16863953, ratio = 0.9981711587749428
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\242.las
# Original numbers of pts = 22885390, numbers of filtering pts = 22849208, ratio = 0.9984189913302767
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\243.las
# Original numbers of pts = 42282096, numbers of filtering pts = 42253508, ratio = 0.9993238745780247
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\244.las
# Original numbers of pts = 97741998, numbers of filtering pts = 97641477, ratio = 0.9989715679845219
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\245.las
# Original numbers of pts = 148183460, numbers of filtering pts = 147877983, ratio = 0.9979385216136808
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\246.las
# Original numbers of pts = 269007, numbers of filtering pts = 269007, ratio = 1.0
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\247.las
# Original numbers of pts = 241947, numbers of filtering pts = 241773, ratio = 0.9992808342322905
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\248.las
# Original numbers of pts = 804988, numbers of filtering pts = 804144, ratio = 0.9989515371657715
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\249.las
# Original numbers of pts = 218814, numbers of filtering pts = 218423, ratio = 0.9982130942261465
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\250.las
# Original numbers of pts = 29022, numbers of filtering pts = 28964, ratio = 0.9980015160912411
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\251.las
# Original numbers of pts = 24721, numbers of filtering pts = 24687, ratio = 0.9986246511063468
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\252.las
# Original numbers of pts = 159319, numbers of filtering pts = 158963, ratio = 0.997765489364106
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\253.las
# Original numbers of pts = 138514, numbers of filtering pts = 138285, ratio = 0.9983467375138975
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\254.las
# Original numbers of pts = 185904, numbers of filtering pts = 185578, ratio = 0.9982464067475686
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\255.las
# Original numbers of pts = 169481, numbers of filtering pts = 169247, ratio = 0.9986193142594155
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\256.las
# Original numbers of pts = 275723, numbers of filtering pts = 275487, ratio = 0.9991440685035343
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\257.las
# Original numbers of pts = 44547, numbers of filtering pts = 44498, ratio = 0.9989000381619413
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\258.las
# Original numbers of pts = 34393, numbers of filtering pts = 34369, ratio = 0.9993021835838688
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\259.las
# Original numbers of pts = 219373, numbers of filtering pts = 218709, ratio = 0.9969731917783866
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\260.las
# Original numbers of pts = 391987, numbers of filtering pts = 391551, ratio = 0.9988877182151449
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\261.las
# Original numbers of pts = 219067, numbers of filtering pts = 218926, ratio = 0.9993563612958593
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\262.las
# Original numbers of pts = 817197, numbers of filtering pts = 816850, ratio = 0.9995753777852832
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\263.las
# Original numbers of pts = 590556, numbers of filtering pts = 590065, ratio = 0.9991685801177196
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\264.las
# Original numbers of pts = 403173, numbers of filtering pts = 402825, ratio = 0.9991368469614781
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\265.las
# Original numbers of pts = 58482, numbers of filtering pts = 58402, ratio = 0.9986320577271639
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\266.las
# Original numbers of pts = 548888, numbers of filtering pts = 547296, ratio = 0.9970995904446809
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\267.las
# Original numbers of pts = 1217492, numbers of filtering pts = 1215831, ratio = 0.9986357199883038
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\268.las
# Original numbers of pts = 445340, numbers of filtering pts = 444586, ratio = 0.9983069115731801
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\269.las
# Original numbers of pts = 1265496, numbers of filtering pts = 1262734, ratio = 0.9978174565545841
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\270.las
# Original numbers of pts = 1471316, numbers of filtering pts = 1467994, ratio = 0.9977421573611651
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\271.las
# Original numbers of pts = 1342304, numbers of filtering pts = 1339378, ratio = 0.9978201659236656
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\272.las
# Original numbers of pts = 1146934, numbers of filtering pts = 1142569, ratio = 0.9961942012356422
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\273.las
# Original numbers of pts = 2808712, numbers of filtering pts = 2803081, ratio = 0.9979951664677618
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\274.las
# Original numbers of pts = 6744866, numbers of filtering pts = 6732664, ratio = 0.998190920323695
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\275.las
# Original numbers of pts = 9546269, numbers of filtering pts = 9537263, ratio = 0.9990565947806416
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\276.las
# Original numbers of pts = 12668410, numbers of filtering pts = 12648091, ratio = 0.9983960891698327
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\277.las
# Original numbers of pts = 3725791, numbers of filtering pts = 3716655, ratio = 0.9975479032506117
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\278.las
# Original numbers of pts = 5011799, numbers of filtering pts = 5002829, ratio = 0.9982102235145504
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\279.las
# Original numbers of pts = 1240761, numbers of filtering pts = 1240680, ratio = 0.9999347174838668
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\280.las
# Original numbers of pts = 7931991, numbers of filtering pts = 7927512, ratio = 0.9994353246240446
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\281.las
# Original numbers of pts = 7160770, numbers of filtering pts = 7152022, ratio = 0.998778343669745
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\282.las
# Original numbers of pts = 2992502, numbers of filtering pts = 2988280, ratio = 0.9985891404583856
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\283.las
# Original numbers of pts = 29146699, numbers of filtering pts = 29139955, ratio = 0.999768618737923
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\284.las
# Original numbers of pts = 19073252, numbers of filtering pts = 19035626, ratio = 0.9980272897353843
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\285.las
# Original numbers of pts = 18493329, numbers of filtering pts = 18471053, ratio = 0.998795457540392
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\286.las
# Original numbers of pts = 59568307, numbers of filtering pts = 59524393, ratio = 0.9992627959025259
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\287.las
# Original numbers of pts = 37183815, numbers of filtering pts = 37147340, ratio = 0.9990190624603742
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\288.las
# Original numbers of pts = 38255449, numbers of filtering pts = 38215300, ratio = 0.9989505024499908
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\289.las
# Original numbers of pts = 30293424, numbers of filtering pts = 30259436, ratio = 0.9988780403298089
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\290.las
# Original numbers of pts = 33604903, numbers of filtering pts = 33554796, ratio = 0.998508937817794
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\291.las
# Original numbers of pts = 36389515, numbers of filtering pts = 36328471, ratio = 0.9983224838253546
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\292.las
# Original numbers of pts = 32898354, numbers of filtering pts = 32844450, ratio = 0.9983614985722385
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\293.las
# Original numbers of pts = 17018749, numbers of filtering pts = 16996657, ratio = 0.9987019022373501
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\294.las
# Original numbers of pts = 47570226, numbers of filtering pts = 47556296, ratio = 0.9997071697746401
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\295.las
# Original numbers of pts = 80789039, numbers of filtering pts = 80693117, ratio = 0.9988126854683839
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\296.las
# Original numbers of pts = 3585129, numbers of filtering pts = 3579209, ratio = 0.9983487344527909
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\297.las
# Original numbers of pts = 118724944, numbers of filtering pts = 118626122, ratio = 0.9991676391104467
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\298.las
# Original numbers of pts = 81094778, numbers of filtering pts = 80903634, ratio = 0.997642955505717
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\299.las
# Original numbers of pts = 460537, numbers of filtering pts = 460257, ratio = 0.9993920141052728
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\300.las
# Original numbers of pts = 10553841, numbers of filtering pts = 10533017, ratio = 0.9980268795029222
# P:/HDmap/Close_Field/LiDAR/RS2003_Xinyi/點雲_LAS\301.las
# Original numbers of pts = 543280, numbers of filtering pts = 542726, ratio = 0.9989802680017671

# %% [markdown]
# # 青埔外圍

# %%
import os, sys, copy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import laspy
from tqdm.notebook import tqdm
from numba import jit, njit, prange
from glob import glob

# %%
las_folder = r"P:/HDmap/Open_Field/LiDAR/QinPu/original/"
fn_list = glob(las_folder+"*.las")
fn_list_tmp = []
for i in fn_list:
    if not "ground" in i:
        fn_list_tmp.append(i)
fn_list = fn_list_tmp
fn = fn_list[0]
print(fn, os.path.basename(fn))
# Out:
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351020100000H.las 桃園青埔_6351020100000H.las

# %%
@njit(parallel=True)
def get_upper_bound(points, min_points_num, upper_bound):
    points_max = np.max(points)
    points_min = np.min(points)
    for i in prange(np.int(points_max-points_min)):
        if np.sum(points_max-i >= points) < min_points_num:
            return upper_bound
        else:
            upper_bound = points_max-i

@njit(parallel=True)
def get_lower_bound(points, min_points_num, lower_bound):
    points_max = np.max(points)
    points_min = np.min(points)
    for i in prange(np.int(points_max-points_min)):
        if np.sum(points_min+i <= points) < min_points_num:
            return lower_bound
        else:
            lower_bound = points_min+i

# %%
# %time
for fn in tqdm(fn_list):
    print(fn)
    inFile = laspy.file.File(os.path.join(las_folder, fn), mode='rw') # read a las file
    las_points = inFile.points.copy()
    min_points_num = int(inFile.x.shape[0]*.999)
    x_upper_bound, y_upper_bound, z_upper_bound = inFile.header.max
    x_lower_bound, y_lower_bound, z_lower_bound = inFile.header.min
    x_upper_bound_new = get_upper_bound(inFile.x, min_points_num, x_upper_bound)
    x_lower_bound_new = get_lower_bound(inFile.x, min_points_num, x_lower_bound)
    y_upper_bound_new = get_upper_bound(inFile.y, min_points_num, y_upper_bound)
    y_lower_bound_new = get_lower_bound(inFile.y, min_points_num, y_lower_bound)
    z_upper_bound_new = get_upper_bound(inFile.z, min_points_num, z_upper_bound)
    z_lower_bound_new = get_lower_bound(inFile.z, min_points_num, z_lower_bound)
    X_valid = (x_lower_bound_new <= inFile.x) * (x_upper_bound_new >= inFile.x)
    Y_valid = (y_lower_bound_new <= inFile.y) * (y_upper_bound_new >= inFile.y)
    Z_valid = (z_lower_bound_new <= inFile.z) * (z_upper_bound_new >= inFile.z)
    good_indices = X_valid * Y_valid * Z_valid
    good_points = las_points[good_indices]
    print(f"Original numbers of pts = {las_points.shape[0]}, numbers of filtering pts = {good_points.shape[0]}, ratio = {good_points.shape[0]/las_points.shape[0]}")
    inFile.header.max = [x_upper_bound_new, y_upper_bound_new, z_upper_bound_new] 
    inFile.header.min = [x_lower_bound_new, y_lower_bound_new, z_lower_bound_new] 
    outFile = laspy.file.File(f"P:/HDmap/Open_Field/LiDAR/QinPu/點雲_過濾極值點_LAS/{os.path.basename(fn)}", mode='w', header=inFile.header)
    outFile.points =  inFile.points[good_indices] 
    outFile.close() 
    inFile.close()
# Out:
# Wall time: 0 ns
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351020100000H.las
# Original numbers of pts = 50411842, numbers of filtering pts = 50305415, ratio = 0.9978888492112628
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351020100000H_1.las
# Original numbers of pts = 32657223, numbers of filtering pts = 32591414, ratio = 0.9979848562138918
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351020100000H_2.las
# Original numbers of pts = 209254123, numbers of filtering pts = 208697363, ratio = 0.9973393116846735
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351020100010H.las
# Original numbers of pts = 49896904, numbers of filtering pts = 49762473, ratio = 0.9973058248263259
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351020100010H_1.las
# Original numbers of pts = 47254162, numbers of filtering pts = 47131292, ratio = 0.9973998057567924
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351320700000H.las
# Original numbers of pts = 58946238, numbers of filtering pts = 58785723, ratio = 0.9972769254587545
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351330700000H.las
# Original numbers of pts = 105676979, numbers of filtering pts = 105283873, ratio = 0.9962801169779844
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351330700010H.las
# Original numbers of pts = 143444934, numbers of filtering pts = 143006825, ratio = 0.9969458036071179
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351330700010H_1.las
# Original numbers of pts = 49327288, numbers of filtering pts = 49228019, ratio = 0.9979875439330863
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351330700020H.las
# Original numbers of pts = 183018296, numbers of filtering pts = 182425990, ratio = 0.9967636787526423
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6351740100000H.las
# Original numbers of pts = 39984543, numbers of filtering pts = 39911433, ratio = 0.9981715434386733
# P:/HDmap/Open_Field/LiDAR/QinPu/original\桃園青埔_6371590100000H.las
# Original numbers of pts = 842988461, numbers of filtering pts = 838941579, ratio = 0.995199362521286
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-35ba37642a69> in <module>
#      22     inFile.header.min = [x_lower_bound_new, y_lower_bound_new, z_lower_bound_new]
#      23     outFile = laspy.file.File(f"P:/HDmap/Open_Field/LiDAR/QinPu/點雲_過濾極值點_LAS/{os.path.basename(fn)}", mode='w', header=inFile.header)
# ---> 24     outFile.points =  inFile.points[good_indices]
#      25     outFile.close()
#      26     inFile.close()
#
# ~\Anaconda3\envs\tf\lib\site-packages\laspy\file.py in set_points(self, new_points)
#     281         or a list/array of laspy.base.Point instances.'''
#     282         self.assertWriteMode()
# --> 283         self._writer.set_points(new_points)
#     284         return
#     285     doc = '''The point data from the file. Get or set the points as either a valid numpy array, or
#
# ~\Anaconda3\envs\tf\lib\site-packages\laspy\base.py in set_points(self, points)
#    1320         if not self.has_point_records:
#    1321             self.has_point_records = True
# -> 1322             self.pad_file_for_point_recs(len(points))
#    1323         if isinstance(points[0], laspy.util.Point):
#    1324             self.data_provider._mmap[self.header.data_offset:self.data_provider._mmap.size()] = b"".join([x.pack() for x in points])
#
# ~\Anaconda3\envs\tf\lib\site-packages\laspy\base.py in pad_file_for_point_recs(self, num_recs)
#    1180             self.data_provider._mmap.flush()
#    1181             self.data_provider.fileref.seek(old_size, 0)
# -> 1182             self.data_provider.fileref.write(b"\x00" * (bytes_to_pad))
#    1183             self.data_provider.fileref.flush()
#    1184             self.data_provider.remap(flush = False, point_map = True)
#
# MemoryError:

# %%
fn_list
# Out:
# ['P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351020100000H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351020100000H_1.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351020100000H_2.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351020100010H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351020100010H_1.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351320700000H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351330700000H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351330700010H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351330700010H_1.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351330700020H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6351740100000H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6371590100000H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6371590100010H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6371600100000H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6379450200000H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6379450600010H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6379450600020H.las',
#  'P:/HDmap/Open_Field/LiDAR/QinPu/original\\桃園青埔_6379490000000H.las']
